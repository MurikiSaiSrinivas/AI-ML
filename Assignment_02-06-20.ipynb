# %% [markdown]
# # Assignment 02-06-20

# %% [markdown]
# # CSE-221710305032-M.Sai Srinivas

# %%
import random
secret_words=["Adorable","Delightful","Homely","Quaint","Adventurous","Depressed","Horrible","Aggressive","Determined","Hungry","Real",
     "Agreeable","Different","Hurt","Relieved","Alert","Difficult","Repulsive","Alive","Disgusted","Ill","Rich","Amused",
     "Distinct","Important","Angry","Disturbed","Impossible","Scary","Annoyed","Dizzy","Inexpensive","Selfish","Annoying",
     "Doubtful","Innocent","Shiny","Anxious","Drab","Inquisitive","Shy","Arrogant","Dull","Itchy","Silly","Ashamed","Sleepy",
     "Attractive","Eager","Jealous","Smiling","Average","Easy","Jittery","Smoggy","Awful","Elated","Jolly","Sore","Elegant",
     "Joyous","Sparkling","Bad","Embarrassed","Splendid","Beautiful","Enchanting","Kind","Spotless","Better","Actor","Gold","Painting","Advertisement","Grass","Parrot","Afternoon","Greece","Pencil","Airport","Guitar","Piano",
      "Ambulance","Hair","Pillow","Animal","Hamburger","Pizza","Answer","Helicopter","Planet","Apple","Helmet","Plastic","Army",
      "Holiday","Portugal","Australia","Honey","Potato","Balloon","Horse","Queen","Banana","Hospital","Quill","Battery",
      "House","Rain","Beach","Hydrogen","Rainbow","Beard","Ice","Raincoat","Bed","Insect","Refrigerator","Belgium",
      "Insurance","Restaurant","Boy","Iron","River","Branch","Island","Rocket","Breakfast","Jackal","Room","Brother","Jelly",
      "Rose","Camera","Jewellery","Russia","Candle","Jordan","Sandwich","Car","Juice","School","Caravan","Kangaroo","Scooter"]
secret_word=random.choice(secret_words).lower()
temp=secret_word
ques=['?' for i in range(len(secret_word))]
lives=9
while lives>0:
    liv=['@' for i in range(lives)]
    print("\n",ques)
    print("Lives left:",liv)
    inp=input("Guess a letter or Word: ").lower()
    lorw=input("Is it a Letter(y/n): ").lower()
    if lorw=='y':
        if inp in secret_word:
            ind=secret_word.index(inp)
            secret_word=secret_word.replace(inp,'?',1)
            ques[ind]=inp
        else:
            print("\nSorry try again")
            lives-=1
    else:
        if inp==temp:
            print("\nCongratulation you guessed crct word \n word:",temp)
            break
        else:
            lives-=1
            print("\nSorry try again")
if lives==0:
    print("You lost the GAME\nAnd correct word is",temp)
# Out:
#  ['?', '?', '?', '?']
# Lives left: ['@', '@', '@', '@', '@', '@', '@', '@', '@']
# Guess a letter or Word: a
# Is it a Letter(y/n): y
#
# Sorry try again
#
#  ['?', '?', '?', '?']
# Lives left: ['@', '@', '@', '@', '@', '@', '@', '@']
# Guess a letter or Word: b
# Is it a Letter(y/n): y
#
# Sorry try again
#
#  ['?', '?', '?', '?']
# Lives left: ['@', '@', '@', '@', '@', '@', '@']
# Guess a letter or Word: c
# Is it a Letter(y/n): y
#
# Sorry try again
#
#  ['?', '?', '?', '?']
# Lives left: ['@', '@', '@', '@', '@', '@']
# Guess a letter or Word: p
# Is it a Letter(y/n): y
#
# Sorry try again
#
#  ['?', '?', '?', '?']
# Lives left: ['@', '@', '@', '@', '@']
# Guess a letter or Word: d
# Is it a Letter(y/n): y
#
# Sorry try again
#
#  ['?', '?', '?', '?']
# Lives left: ['@', '@', '@', '@']
# Guess a letter or Word: z
# Is it a Letter(y/n): y
#
# Sorry try again
#
#  ['?', '?', '?', '?']
# Lives left: ['@', '@', '@']
# Guess a letter or Word: n
# Is it a Letter(y/n): y
#
#  ['?', '?', '?', 'n']
# Lives left: ['@', '@', '@']
# Guess a letter or Word: e
# Is it a Letter(y/n): y
#
# Sorry try again
#
#  ['?', '?', '?', 'n']
# Lives left: ['@', '@']
# Guess a letter or Word: t
# Is it a Letter(y/n): y
#
# Sorry try again
#
#  ['?', '?', '?', 'n']
# Lives left: ['@']
# Guess a letter or Word: v
# Is it a Letter(y/n): y
#
# Sorry try again
# You lost the GAME
# And correct word is iron
